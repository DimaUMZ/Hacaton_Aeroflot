# %% [markdown]
# ### 1. Подключаем библиотеки

# %%
import os
import yaml
from ultralytics import YOLO
import cv2
import numpy as np
from sklearn.model_selection import train_test_split
import shutil
import random
from pathlib import Path

# %% [markdown]
# ### 2. Подготовка датасета

# %% [markdown]
# ##### Копируем изображения и создаем аннотации

# %%
def copy_images_with_annotations(src_dir, output_dir, class_idx, split, images, bbox_coords=(0.5, 0.5, 1.0, 1.0)):
    """Копирует изображения и создает аннотации"""
    for img_name in images:
        try:
            # Копируем изображение
            src_img = os.path.join(src_dir, img_name)
            dst_img = os.path.join(output_dir, 'images', split, img_name)
            shutil.copy2(src_img, dst_img)
            
            # Создаем YOLO аннотацию
            txt_name = os.path.splitext(img_name)[0] + '.txt'
            with open(os.path.join(output_dir, 'labels', split, txt_name), 'w') as f:
                f.write(f"{class_idx} {bbox_coords[0]} {bbox_coords[1]} {bbox_coords[2]} {bbox_coords[3]}\n")
                        
        except Exception as e:
            print(f"❌ Ошибка при обработке {img_name}: {e}")

# %% [markdown]
# ##### Обрабатываем данные и проверяем результат

# %%
def process_single_tools(dataset_path, output_dir, classes):
    """Обрабатывает папки с отдельными инструментами"""
    print("\n=== Обработка отдельных инструментов ===")
    
    total_images = 0
    for class_idx, class_name in enumerate(classes):
        class_path = os.path.join(dataset_path, class_name)
        
        if not os.path.exists(class_path):
            print(f"⚠ Предупреждение: папка {class_path} не существует!")
            continue
            
        images = [f for f in os.listdir(class_path) 
                 if f.lower().endswith(('.jpg', '.jpeg', '.png', '.bmp', '.tiff'))]
        
        print(f"{class_name}: {len(images)} изображений")
        
        if len(images) == 0:
            print(f"⚠ Предупреждение: в папке {class_name} нет изображений!")
            continue
        
        # Разделяем на train/val
        if len(images) == 1:
            train_imgs = images
            val_imgs = []
        else:
            train_imgs, val_imgs = train_test_split(images, test_size=0.2, random_state=42, shuffle=True)
        
        print(f"  Train: {len(train_imgs)}, Val: {len(val_imgs)}")
        total_images += len(images)
        
        # Копируем изображения и создаем аннотации
        copy_images_with_annotations(class_path, output_dir, class_idx, 'train', train_imgs, 
                                   bbox_coords=(0.5, 0.5, 1.0, 1.0))  # Весь изображение
        copy_images_with_annotations(class_path, output_dir, class_idx, 'val', val_imgs,
                                   bbox_coords=(0.5, 0.5, 1.0, 1.0))
    
    print(f"✓ Обработано отдельных инструментов: {total_images} изображений")

def process_group_photos(dataset_path, output_dir, group_folders):
    """Обрабатывает групповые фотографии"""
    print("\n=== Обработка групповых фото ===")
    
    total_images = 0
    for group_folder in group_folders:
        group_path = os.path.join(dataset_path, group_folder)
        images = [f for f in os.listdir(group_path) 
                 if f.lower().endswith(('.jpg', '.jpeg', '.png', '.bmp', '.tiff'))]
        
        print(f"{group_folder}: {len(images)} изображений")
        
        if len(images) == 0:
            print(f"⚠ Предупреждение: в папке {group_folder} нет изображений!")
            continue
        
        total_images += len(images)
        
        # Для групповых фото используем все изображения для тренировки
        for img_name in images:
            try:
                # Копируем изображение в train
                src_img = os.path.join(group_path, img_name)
                dst_img = os.path.join(output_dir, 'images', 'train', img_name)
                shutil.copy2(src_img, dst_img)
                
                # Проверяем есть ли аннотация
                txt_name = os.path.splitext(img_name)[0] + '.txt'
                annotation_path = os.path.join(group_path, txt_name)
                
                if os.path.exists(annotation_path):
                    # Копируем существующую аннотацию
                    dst_txt = os.path.join(output_dir, 'labels', 'train', txt_name)
                    shutil.copy2(annotation_path, dst_txt)
                    print(f"  ✓ Добавлена аннотация для {img_name}")
                else:
                    # Создаем пустую аннотацию (нужно будет аннотировать вручную)
                    dst_txt = os.path.join(output_dir, 'labels', 'train', txt_name)
                    with open(dst_txt, 'w') as f:
                        # Пустой файл - нужно добавить bounding boxes вручную
                        pass
                    print(f"  ⚠ Создана пустая аннотация для {img_name} (требует ручной разметки)")
                    
            except Exception as e:
                print(f"❌ Ошибка при обработке группового фото {img_name}: {e}")
    
    print(f"✓ Обработано групповых фото: {total_images} изображений")
    
def check_dataset_stats(output_dir):
    """Проверяет статистику подготовленного датасета"""
    print("\n=== Статистика датасета ===")
    
    train_images = len(os.listdir(os.path.join(output_dir, 'images', 'train')))
    val_images = len(os.listdir(os.path.join(output_dir, 'images', 'val')))
    train_labels = len(os.listdir(os.path.join(output_dir, 'labels', 'train')))
    val_labels = len(os.listdir(os.path.join(output_dir, 'labels', 'val')))
    
    print(f"✓ Тренировочные изображения: {train_images}")
    print(f"✓ Валидационные изображения: {val_images}")
    print(f"✓ Тренировочные аннотации: {train_labels}")
    print(f"✓ Валидационные аннотации: {val_labels}")
    print(f"✓ Общее количество изображений: {train_images + val_images}")

# %% [markdown]
# ##### Основная функция

# %%
def prepare_yolo_dataset(dataset_path, output_dir='yolo_dataset'):
    """
    Подготавливает датасет в формате YOLO
    """
    # Получаем все папки
    all_folders = sorted([d for d in os.listdir(dataset_path) 
                         if os.path.isdir(os.path.join(dataset_path, d))])
    
    print(f"Найдено папок: {len(all_folders)}")
    print("Все папки:", all_folders)
    
    # Создаем директории
    for split in ['train', 'val']:
        os.makedirs(os.path.join(output_dir, 'images', split), exist_ok=True)
        os.makedirs(os.path.join(output_dir, 'labels', split), exist_ok=True)
    
    # Разделяем папки по типам
    tools_folders = [folder for folder in all_folders 
                    if 'групповые' not in folder.lower() 
                    and 'линейк' not in folder.lower()
                    and 'group' not in folder.lower()
                    and 'ruler' not in folder.lower()]
    
    group_folders = [folder for folder in all_folders 
                    if 'групповые' in folder.lower() 
                    or 'group' in folder.lower()]
    
    print(f"✓ Папки с инструментами: {len(tools_folders)}")
    print("Инструменты:", tools_folders)
    print(f"Групповые папки: {len(group_folders)}")
    
    # Сохраняем классы инструментов
    with open(os.path.join(output_dir, 'classes.txt'), 'w') as f:
        for i, class_name in enumerate(tools_folders):
            f.write(f"{class_name}\n")
    
    # Обрабатываем данные
    process_single_tools(dataset_path, output_dir, tools_folders)
    process_group_photos(dataset_path, output_dir, group_folders)
    
    # Проверяем результат
    check_dataset_stats(output_dir)
    
    return tools_folders

# %% [markdown]
# ### 3. Создание конфигурации

# %%
def create_dataset_config(output_dir='yolo_dataset', output_yaml='dataset.yaml'):
    """
    Создает конфигурационный файл для датасета YOLO
    """
    # Читаем классы из файла
    classes_path = os.path.join(output_dir, 'classes.txt')
    if not os.path.exists(classes_path):
        print(f"Ошибка: файл {classes_path} не найден!")
        return None, None
    
    with open(classes_path, 'r') as f:
        classes = [line.strip() for line in f.readlines()]
    
    # Создаем словарь с конфигурацией
    config = {
        'path': os.path.abspath(output_dir),
        'train': 'images/train',
        'val': 'images/val',
        'nc': len(classes),
        'names': {i: class_name for i, class_name in enumerate(classes)}
    }
    
    # Сохраняем в YAML файл
    with open(output_yaml, 'w') as f:
        yaml.dump(config, f, default_flow_style=False, allow_unicode=True)
    
    print(f"✓ Создан конфиг файл: {output_yaml}")
    print(f"✓ Путь к данным: {os.path.abspath(output_dir)}")
    print(f"✓ Количество классов: {len(classes)}")
    return config, classes

# %% [markdown]
# ### 4. Обучение модели

# %%
def train_yolo_model(output_dir='yolo_dataset', model_size='s', epochs=100):
    """
    Обучение модели YOLOv8 с улучшенными параметрами
    """
    # Создаем конфигурационный файл
    config, classes = create_dataset_config(output_dir)
    
    if config is None:
        raise ValueError("Не удалось создать конфигурационный файл")
    
    # Загружаем предобученную модель
    print(f"🚀 Загрузка модели YOLOv8{model_size}.pt...")
    model = YOLO(f'yolov8{model_size}.pt')
    
    # Расширенные параметры обучения
    train_params = {
        'data': 'dataset.yaml',
        'epochs': epochs,
        'imgsz': 640,
        'batch': 16,
        'name': f'yolov8{model_size}_tools_detection_v2',
        'patience': 20,
        'optimizer': 'AdamW',
        'lr0': 0.001,
        'lrf': 0.01,
        'momentum': 0.937,
        'weight_decay': 0.0005,
        'augment': True,
        'hsv_h': 0.015,
        'hsv_s': 0.7,
        'hsv_v': 0.4,
        'degrees': 45,
        'translate': 0.1,
        'scale': 0.5,
        'shear': 0.0,
        'perspective': 0.0,
        'flipud': 0.0,
        'fliplr': 0.5,
        'mosaic': 1.0,
        'mixup': 0.1,
        'copy_paste': 0.1,
        'erasing': 0.4,
        'dropout': 0.1,
        'val': True,
        'save': True,
        'save_period': 10,
        #'device': 0,  # Использовать GPU если доступен
        'workers': 8,
        'single_cls': False,
        'verbose': True,
        'exist_ok': True
    }
    
    print("🎯 Начинаем обучение модели...")
    print(f"📊 Параметры обучения: {epochs} эпох, размер батча: 16")
    
    # Обучаем модель
    results = model.train(**train_params)
    
    return model, results

# %% [markdown]
# ### 5. Экспорт в ONNX

# %%
def export_model_to_onnx(model, output_path='yolov8_tools.onnx'):
    """
    Экспорт модели в формат ONNX с оптимизацией
    """
    print("📤 Экспорт модели в ONNX...")
    model.export(format='onnx', imgsz=640, simplify=True, dynamic=True, opset=12)
    print(f"✅ Модель экспортирована в: {output_path}")

# %% [markdown]
# ### 6. Оценка модели

# %%
def evaluate_model(model, data_path='yolo_dataset'):
    """
    Оценка модели на тестовых данных
    """
    print("📊 Оценка модели...")
    metrics = model.val(data=os.path.join(data_path, 'dataset.yaml'), split='val')
    return metrics

# %% [markdown]
# ### 7. Тестирование

# %%
def predict_on_image(model, image_path, conf_threshold=0.25, iou_threshold=0.45):
    """
    Предсказание на одном изображении с улучшенной визуализацией
    """
    # Выполняем предсказание
    results = model(image_path, conf=conf_threshold, iou=iou_threshold, augment=True)
    
    # Визуализируем результаты
    for i, result in enumerate(results):
        # Рисуем bounding boxes с улучшенной визуализацией
        img = result.plot(line_width=2, font_size=1.0, conf=True, labels=True)
        
        # Создаем окно с фиксированным размером
        height, width = img.shape[:2]
        max_display_size = 1200
        if max(height, width) > max_display_size:
            scale = max_display_size / max(height, width)
            new_width = int(width * scale)
            new_height = int(height * scale)
            img = cv2.resize(img, (new_width, new_height))
        
        cv2.imshow('Инструменты - обнаружение', img)
        cv2.waitKey(0)
        cv2.destroyAllWindows()
        
        # Детальная информация об обнаруженных объектах
        print(f"\n🔍 Результаты обнаружения для изображения {i+1}:")
        if len(result.boxes) > 0:
            for j, box in enumerate(result.boxes):
                class_id = int(box.cls[0])
                confidence = float(box.conf[0])
                bbox = box.xyxy[0].cpu().numpy()
                print(f"  Объект {j+1}: {model.names[class_id]} "
                      f"(уверенность: {confidence:.3f}) "
                      f"BBox: {bbox.astype(int)}")
        else:
            print("  Объекты не обнаружены")
    
    return results

# %% [markdown]
# ### 8. Основная функция

# %%
def main():
    # Пути к данным
    dataset_path = '/data/vscode/HacatonAeroflot/Aeroflot-project/datasets/raw'
    output_dir = '/data/vscode/HacatonAeroflot/Aeroflot-project/yolo_dataset'
    
    try:
        # Проверяем существование пути
        if not os.path.exists(dataset_path):
            print(f"❌ Ошибка: путь {dataset_path} не существует!")
            return
        
        print("=" * 60)
        print("🛠️  СИСТЕМА ОБНАРУЖЕНИЯ ИНСТРУМЕНТОВ")
        print("=" * 60)
        
        # Шаг 1: Подготовка датасета
        print("\n📁 ШАГ 1: Подготовка датасета...")
        classes = prepare_yolo_dataset(dataset_path, output_dir)
        
        # Шаг 2: Создание конфигурации
        print("\n⚙️  ШАГ 2: Создание конфигурации...")
        config, classes = create_dataset_config(output_dir)
        
        if config is None:
            raise ValueError("Не удалось создать конфигурацию датасета")
        
        # Шаг 3: Обучение модели
        print("\n🎓 ШАГ 3: Обучение модели...")
        model, results = train_yolo_model(output_dir, model_size='s', epochs=100)
        
        # Шаг 4: Сохранение модели
        print("\n💾 ШАГ 4: Сохранение модели...")
        model.save('best_tools_detection.pt')
        print("✅ Модель сохранена как 'best_tools_detection.pt'")
        
        # Шаг 5: Экспорт в ONNX
        print("\n📤 ШАГ 5: Экспорт в ONNX...")
        export_model_to_onnx(model)
        
        # Шаг 6: Оценка модели
        print("\n📊 ШАГ 6: Оценка модели...")
        metrics = evaluate_model(model, output_dir)
        
        # Шаг 7: Тестирование
        print("\n🧪 ШАГ 7: Тестирование модели...")
        
        # Ищем тестовое изображение
        test_images_dir = os.path.join(output_dir, 'images', 'val')
        if os.path.exists(test_images_dir):
            test_images = os.listdir(test_images_dir)
            if test_images:
                test_image_path = os.path.join(test_images_dir, test_images[0])
                print(f"Тестируем на изображении: {test_images[0]}")
                predict_on_image(model, test_image_path)
            else:
                print("⚠ Тестовые изображения не найдены")
        else:
            print("⚠ Папка с тестовыми изображениями не найдена")
        
        print("\n" + "=" * 60)
        print("✅ ВСЕ ЭТАПЫ ЗАВЕРШЕНЫ УСПЕШНО!")
        print("=" * 60)
        
    except Exception as e:
        print(f"\n❌ КРИТИЧЕСКАЯ ОШИБКА: {e}")
        import traceback
        traceback.print_exc()

if __name__ == "__main__":
    main()
# Out:
# ============================================================
# 🛠️  СИСТЕМА ОБНАРУЖЕНИЯ ИНСТРУМЕНТОВ
# ============================================================
#
# 📁 ШАГ 1: Подготовка датасета...
# Найдено папок: 13
# Все папки: ['1 Отвертка «-»', '10 Ключ рожковыйнакидной  ¾', '11 Бокорезы', '2 Отвертка «+»', '3 Отвертка на смещенный крест', '4 Коловорот', '5 Пассатижи контровочные', '6 Пассатижи', '7 Шэрница', '8 Разводной ключ', '9 Открывашка для банок с маслом', 'Групповые для тренировки', 'Инструменты с линейкой']
# ✓ Папки с инструментами: 11
# Инструменты: ['1 Отвертка «-»', '10 Ключ рожковыйнакидной  ¾', '11 Бокорезы', '2 Отвертка «+»', '3 Отвертка на смещенный крест', '4 Коловорот', '5 Пассатижи контровочные', '6 Пассатижи', '7 Шэрница', '8 Разводной ключ', '9 Открывашка для банок с маслом']
# Групповые папки: 1
#
# === Обработка отдельных инструментов ===
# 1 Отвертка «-»: 247 изображений
#   Train: 197, Val: 50
# ❌ Ошибка при обработке DSCN2506.JPG: [Errno 1] Operation not permitted
# ❌ Ошибка при обработке DSCN2575.JPG: [Errno 1] Operation not permitted
# ❌ Ошибка при обработке DSCN4813.JPG: [Errno 1] Operation not permitted
# ❌ Ошибка при обработке DSCN2497.JPG: [Errno 1] Operation not permitted
# ❌ Ошибка при обработке DSCN2573.JPG: [Errno 1] Operation not permitted
# ❌ Ошибка при обработке DSCN2452.JPG: [Errno 1] Operation not permitted
# ❌ Ошибка при обработке DSCN2492.JPG: [Errno 1] Operation not permitted
# ❌ Ошибка при обработке DSCN2593.JPG: [Errno 1] Operation not permitted
# ❌ Ошибка при обработке DSCN2477.JPG: [Errno 1] Operation not permitted
# ❌ Ошибка при обработке DSCN2583.JPG: [Errno 1] Operation not permitted
# ❌ Ошибка при обработке DSCN2507.JPG: [Errno 1] Operation not permitted
# ❌ Ошибка при обработке DSCN2510.JPG: [Errno 1] Operation not permitted
# ❌ Ошибка при обработке DSCN2508.JPG: [Errno 1] Operation not permitted
# ❌ Ошибка при обработке DSCN2584.JPG: [Errno 1] Operation not permitted
# ❌ Ошибка при обработке DSCN2446.JPG: [Errno 1] Operation not permitted
# ❌ Ошибка при обработке DSCN2588.JPG: [Errno 1] Operation not permitted
# ❌ Ошибка при обработке DSCN2442.JPG: [Errno 1] Operation not permitted
# ❌ Ошибка при обработке DSCN2389.JPG: [Errno 1] Operation not permitted
# ❌ Ошибка при обработке DSCN2596.JPG: [Errno 1] Operation not permitted
# ❌ Ошибка при обработке DSCN2567.JPG: [Errno 1] Operation not permitted
# ❌ Ошибка при обработке DSCN2505.JPG: [Errno 1] Operation not permitted
# ❌ Ошибка при обработке DSCN2478.JPG: [Errno 1] Operation not permitted
# ❌ Ошибка при обработке DSCN2453.JPG: [Errno 1] Operation not permitted
# ❌ Ошибка при обработке DSCN4819.JPG: [Errno 1] Operation not permitted
# ❌ Ошибка при обработке DSCN2484.JPG: [Errno 1] Operation not permitted
# ❌ Ошибка при обработке DSCN2395.JPG: [Errno 1] Operation not permitted
# ❌ Ошибка при обработке DSCN2417.JPG: [Errno 1] Operation not permitted
# ❌ Ошибка при обработке DSCN2590.JPG: [Errno 1] Operation not permitted
# ❌ Ошибка при обработке DSCN2533.JPG: [Errno 1] Operation not permitted
# ❌ Ошибка при обработке DSCN2518.JPG: [Errno 1] Operation not permitted
# ❌ Ошибка при обработке DSCN2564.JPG: [Errno 1] Operation not permitted
# ❌ Ошибка при обработке DSCN4815.JPG: [Errno 1] Operation not permitted
# ❌ Ошибка при обработке DSCN2511.JPG: [Errno 1] Operation not permitted
# ❌ Ошибка при обработке DSCN2592.JPG: [Errno 1] Operation not permitted
# ❌ Ошибка при обработке DSCN2529.JPG: [Errno 1] Operation not permitted
# ❌ Ошибка при обработке DSCN2390.JPG: [Errno 1] Operation not permitted
# ❌ Ошибка при обработке DSCN2599.JPG: [Errno 1] Operation not permitted
# ❌ Ошибка при обработке DSCN2486.JPG: [Errno 1] Operation not permitted
# ❌ Ошибка при обработке DSCN2571.JPG: [Errno 1] Operation not permitted
# ❌ Ошибка при обработке DSCN2526.JPG: [Errno 1] Operation not permitted
# ❌ Ошибка при обработке DSCN2600.JPG: [Errno 1] Operation not permitted
# ❌ Ошибка при обработке DSCN2499.JPG: [Errno 1] Operation not permitted
# ❌ Ошибка при обработке DSCN2585.JPG: [Errno 1] Operation not permitted
# ❌ Ошибка при обработке DSCN2388.JPG: [Errno 1] Operation not permitted
# ❌ Ошибка при обработке DSCN2413.JPG: [Errno 1] Operation not permitted
# ❌ Ошибка при обработке DSCN2405.JPG: [Errno 1] Operation not permitted
# ❌ Ошибка при обработке DSCN2532.JPG: [Errno 1] Operation not permitted
# ❌ Ошибка при обработке DSCN2428.JPG: [Errno 1] Operation not permitted
# ❌ Ошибка при обработке DSCN2528.JPG: [Errno 1] Operation not permitted
# ❌ Ошибка при обработке DSCN2545.JPG: [Errno 1] Operation not permitted
# ❌ Ошибка при обработке DSCN4831.JPG: [Errno 1] Operation not permitted
# ❌ Ошибка при обработке DSCN2542.JPG: [Errno 1] Operation not permitted
# ❌ Ошибка при обработке DSCN2441.JPG: [Errno 1] Operation not permitted
# ❌ Ошибка при обработке DSCN2500.JPG: [Errno 1] Operation not permitted
# ❌ Ошибка при обработке DSCN2464.JPG: [Errno 1] Operation not permitted
# ❌ Ошибка при обработке DSCN2556.JPG: [Errno 1] Operation not permitted
# ❌ Ошибка при обработке DSCN2386.JPG: [Errno 1] Operation not permitted
# ❌ Ошибка при обработке DSCN2559.JPG: [Errno 1] Operation not permitted
# ❌ Ошибка при обработке DSCN2430.JPG: [Errno 1] Operation not permitted
# ❌ Ошибка при обработке DSCN2514.JPG: [Errno 1] Operation not permitted
# ❌ Ошибка при обработке DSCN2597.JPG: [Errno 1] Operation not permitted
# ❌ Ошибка при обработке DSCN2472.JPG: [Errno 1] Operation not permitted
# ❌ Ошибка при обработке DSCN2581.JPG: [Errno 1] Operation not permitted
# ❌ Ошибка при обработке DSCN2426.JPG: [Errno 1] Operation not permitted
# ❌ Ошибка при обработке DSCN2487.JPG: [Errno 1] Operation not permitted
# ❌ Ошибка при обработке DSCN4830.JPG: [Errno 1] Operation not permitted
# ❌ Ошибка при обработке DSCN4826.JPG: [Errno 1] Operation not permitted
# ❌ Ошибка при обработке DSCN2419.JPG: [Errno 1] Operation not permitted
# ❌ Ошибка при обработке DSCN2568.JPG: [Errno 1] Operation not permitted
# ❌ Ошибка при обработке DSCN2482.JPG: [Errno 1] Operation not permitted
# ❌ Ошибка при обработке DSCN2385.JPG: [Errno 1] Operation not permitted
# ❌ Ошибка при обработке DSCN2603.JPG: [Errno 1] Operation not permitted
# ❌ Ошибка при обработке DSCN2554.JPG: [Errno 1] Operation not permitted
# ❌ Ошибка при обработке DSCN2444.JPG: [Errno 1] Operation not permitted
# ❌ Ошибка при обработке DSCN4825.JPG: [Errno 1] Operation not permitted
# ❌ Ошибка при обработке DSCN2517.JPG: [Errno 1] Operation not permitted
# ❌ Ошибка при обработке DSCN2537.JPG: [Errno 1] Operation not permitted
# ❌ Ошибка при обработке DSCN2547.JPG: [Errno 1] Operation not permitted
# ❌ Ошибка при обработке DSCN2523.JPG: [Errno 1] Operation not permitted
# ❌ Ошибка при обработке DSCN2449.JPG: [Errno 1] Operation not permitted
# ❌ Ошибка при обработке DSCN2462.JPG: [Errno 1] Operation not permitted
# ❌ Ошибка при обработке DSCN2427.JPG: [Errno 1] Operation not permitted
# ❌ Ошибка при обработке DSCN4824.JPG: [Errno 1] Operation not permitted
# ❌ Ошибка при обработке DSCN2399.JPG: [Errno 1] Operation not permitted
# ❌ Ошибка при обработке DSCN4817.JPG: [Errno 1] Operation not permitted
# ❌ Ошибка при обработке DSCN2541.JPG: [Errno 1] Operation not permitted
# ❌ Ошибка при обработке DSCN4834.JPG: [Errno 1] Operation not permitted
# ❌ Ошибка при обработке DSCN2558.JPG: [Errno 1] Operation not permitted
# ❌ Ошибка при обработке DSCN2420.JPG: [Errno 1] Operation not permitted
# ❌ Ошибка при обработке DSCN2476.JPG: [Errno 1] Operation not permitted
# ❌ Ошибка при обработке DSCN2398.JPG: [Errno 1] Operation not permitted
# ❌ Ошибка при обработке DSCN2489.JPG: [Errno 1] Operation not permitted
# ❌ Ошибка при обработке DSCN2471.JPG: [Errno 1] Operation not permitted
# ❌ Ошибка при обработке DSCN2501.JPG: [Errno 1] Operation not permitted
# ❌ Ошибка при обработке DSCN2465.JPG: [Errno 1] Operation not permitted
# ❌ Ошибка при обработке DSCN2551.JPG: [Errno 1] Operation not permitted
# ❌ Ошибка при обработке DSCN2396.JPG: [Errno 1] Operation not permitted
# ❌ Ошибка при обработке DSCN2391.JPG: [Errno 1] Operation not permitted
# ❌ Ошибка при обработке DSCN4827.JPG: [Errno 1] Operation not permitted
# ❌ Ошибка при обработке DSCN2483.JPG: [Errno 1] Operation not permitted
# ❌ Ошибка при обработке DSCN2540.JPG: [Errno 1] Operation not permitted
# ❌ Ошибка при обработке DSCN2423.JPG: [Errno 1] Operation not permitted
# ❌ Ошибка при обработке DSCN2509.JPG: [Errno 1] Operation not permitted
# ❌ Ошибка при обработке DSCN2531.JPG: [Errno 1] Operation not permitted
# ❌ Ошибка при обработке DSCN2602.JPG: [Errno 1] Operation not permitted
# ❌ Ошибка при обработке DSCN2466.JPG: [Errno 1] Operation not permitted
# ❌ Ошибка при обработке DSCN4823.JPG: [Errno 1] Operation not permitted
# ❌ Ошибка при обработке DSCN2455.JPG: [Errno 1] Operation not permitted
# ❌ Ошибка при обработке DSCN2479.JPG: [Errno 1] Operation not permitted
# ❌ Ошибка при обработке DSCN2512.JPG: [Errno 1] Operation not permitted
# ❌ Ошибка при обработке DSCN4807.JPG: [Errno 1] Operation not permitted
# ❌ Ошибка при обработке DSCN2433.JPG: [Errno 1] Operation not permitted
# ❌ Ошибка при обработке DSCN2546.JPG: [Errno 1] Operation not permitted
# ❌ Ошибка при обработке DSCN2503.JPG: [Errno 1] Operation not permitted
# ❌ Ошибка при обработке DSCN2467.JPG: [Errno 1] Operation not permitted
# ❌ Ошибка при обработке DSCN2494.JPG: [Errno 1] Operation not permitted
# ❌ Ошибка при обработке DSCN2502.JPG: [Errno 1] Operation not permitted
# ❌ Ошибка при обработке DSCN2582.JPG: [Errno 1] Operation not permitted
# ❌ Ошибка при обработке DSCN2411.JPG: [Errno 1] Operation not permitted
# ❌ Ошибка при обработке DSCN2410.JPG: [Errno 1] Operation not permitted
# ❌ Ошибка при обработке DSCN4806.JPG: [Errno 1] Operation not permitted
# ❌ Ошибка при обработке DSCN4812.JPG: [Errno 1] Operation not permitted
# ❌ Ошибка при обработке DSCN2520.JPG: [Errno 1] Operation not permitted
# ❌ Ошибка при обработке DSCN4821.JPG: [Errno 1] Operation not permitted
# ❌ Ошибка при обработке DSCN2445.JPG: [Errno 1] Operation not permitted
# ❌ Ошибка при обработке DSCN2572.JPG: [Errno 1] Operation not permitted
# ❌ Ошибка при обработке DSCN4811.JPG: [Errno 1] Operation not permitted
# ❌ Ошибка при обработке DSCN2459.JPG: [Errno 1] Operation not permitted
# ❌ Ошибка при обработке DSCN2543.JPG: [Errno 1] Operation not permitted
# ❌ Ошибка при обработке DSCN4833.JPG: [Errno 1] Operation not permitted
# ❌ Ошибка при обработке DSCN2401.JPG: [Errno 1] Operation not permitted
# ❌ Ошибка при обработке DSCN2435.JPG: [Errno 1] Operation not permitted
# ❌ Ошибка при обработке DSCN2473.JPG: [Errno 1] Operation not permitted
# ❌ Ошибка при обработке DSCN2496.JPG: [Errno 1] Operation not permitted
# ❌ Ошибка при обработке DSCN2448.JPG: [Errno 1] Operation not permitted
# ❌ Ошибка при обработке DSCN2434.JPG: [Errno 1] Operation not permitted
# ❌ Ошибка при обработке DSCN2587.JPG: [Errno 1] Operation not permitted
# ❌ Ошибка при обработке DSCN2525.JPG: [Errno 1] Operation not permitted
# ❌ Ошибка при обработке DSCN2527.JPG: [Errno 1] Operation not permitted
# ❌ Ошибка при обработке DSCN2488.JPG: [Errno 1] Operation not permitted
# ❌ Ошибка при обработке DSCN2591.JPG: [Errno 1] Operation not permitted
# ❌ Ошибка при обработке DSCN2577.JPG: [Errno 1] Operation not permitted
# ❌ Ошибка при обработке DSCN2570.JPG: [Errno 1] Operation not permitted
# ❌ Ошибка при обработке DSCN2589.JPG: [Errno 1] Operation not permitted
# ❌ Ошибка при обработке DSCN2394.JPG: [Errno 1] Operation not permitted
# ❌ Ошибка при обработке DSCN2516.JPG: [Errno 1] Operation not permitted
# ❌ Ошибка при обработке DSCN4808.JPG: [Errno 1] Operation not permitted
# ❌ Ошибка при обработке DSCN2415.JPG: [Errno 1] Operation not permitted
# ❌ Ошибка при обработке DSCN2480.JPG: [Errno 1] Operation not permitted
# ❌ Ошибка при обработке DSCN2457.JPG: [Errno 1] Operation not permitted
# ❌ Ошибка при обработке DSCN2586.JPG: [Errno 1] Operation not permitted
# ❌ Ошибка при обработке DSCN2560.JPG: [Errno 1] Operation not permitted
# ❌ Ошибка при обработке DSCN2454.JPG: [Errno 1] Operation not permitted
# ❌ Ошибка при обработке DSCN2451.JPG: [Errno 1] Operation not permitted
# ❌ Ошибка при обработке DSCN2418.JPG: [Errno 1] Operation not permitted
# ❌ Ошибка при обработке DSCN2431.JPG: [Errno 1] Operation not permitted
# ❌ Ошибка при обработке DSCN4818.JPG: [Errno 1] Operation not permitted
# ❌ Ошибка при обработке DSCN2468.JPG: [Errno 1] Operation not permitted
# ❌ Ошибка при обработке DSCN2535.JPG: [Errno 1] Operation not permitted
# ❌ Ошибка при обработке DSCN2424.JPG: [Errno 1] Operation not permitted
# ❌ Ошибка при обработке DSCN2393.JPG: [Errno 1] Operation not permitted
# ❌ Ошибка при обработке DSCN2461.JPG: [Errno 1] Operation not permitted
# ❌ Ошибка при обработке DSCN2392.JPG: [Errno 1] Operation not permitted
# ❌ Ошибка при обработке DSCN2432.JPG: [Errno 1] Operation not permitted
# ❌ Ошибка при обработке DSCN2566.JPG: [Errno 1] Operation not permitted
# ❌ Ошибка при обработке DSCN2538.JPG: [Errno 1] Operation not permitted
# ❌ Ошибка при обработке DSCN2563.JPG: [Errno 1] Operation not permitted
# ❌ Ошибка при обработке DSCN4828.JPG: [Errno 1] Operation not permitted
# ❌ Ошибка при обработке DSCN2574.JPG: [Errno 1] Operation not permitted
# ❌ Ошибка при обработке DSCN2474.JPG: [Errno 1] Operation not permitted
# ❌ Ошибка при обработке DSCN2456.JPG: [Errno 1] Operation not permitted
# ❌ Ошибка при обработке DSCN2553.JPG: [Errno 1] Operation not permitted
# ❌ Ошибка при обработке DSCN2548.JPG: [Errno 1] Operation not permitted
# ❌ Ошибка при обработке DSCN2407.JPG: [Errno 1] Operation not permitted
# ❌ Ошибка при обработке DSCN2601.JPG: [Errno 1] Operation not permitted
# ❌ Ошибка при обработке DSCN2436.JPG: [Errno 1] Operation not permitted
# ❌ Ошибка при обработке DSCN2490.JPG: [Errno 1] Operation not permitted
# ❌ Ошибка при обработке DSCN2463.JPG: [Errno 1] Operation not permitted
# ❌ Ошибка при обработке DSCN2439.JPG: [Errno 1] Operation not permitted
# ❌ Ошибка при обработке DSCN2414.JPG: [Errno 1] Operation not permitted
# ❌ Ошибка при обработке DSCN2594.JPG: [Errno 1] Operation not permitted
# ❌ Ошибка при обработке DSCN2495.JPG: [Errno 1] Operation not permitted
# ❌ Ошибка при обработке DSCN2475.JPG: [Errno 1] Operation not permitted
# ❌ Ошибка при обработке DSCN2422.JPG: [Errno 1] Operation not permitted
# ❌ Ошибка при обработке DSCN2416.JPG: [Errno 1] Operation not permitted
# ❌ Ошибка при обработке DSCN2450.JPG: [Errno 1] Operation not permitted
# ❌ Ошибка при обработке DSCN2569.JPG: [Errno 1] Operation not permitted
# ❌ Ошибка при обработке DSCN4829.JPG: [Errno 1] Operation not permitted
# ❌ Ошибка при обработке DSCN2576.JPG: [Errno 1] Operation not permitted
# ❌ Ошибка при обработке DSCN2400.JPG: [Errno 1] Operation not permitted
# ❌ Ошибка при обработке DSCN2406.JPG: [Errno 1] Operation not permitted
# ❌ Ошибка при обработке DSCN2408.JPG: [Errno 1] Operation not permitted
# ❌ Ошибка при обработке DSCN2402.JPG: [Errno 1] Operation not permitted
# ❌ Ошибка при обработке DSCN2521.JPG: [Errno 1] Operation not permitted
# ❌ Ошибка при обработке DSCN2555.JPG: [Errno 1] Operation not permitted
# ❌ Ошибка при обработке DSCN2550.JPG: [Errno 1] Operation not permitted
# ❌ Ошибка при обработке DSCN2530.JPG: [Errno 1] Operation not permitted
# ❌ Ошибка при обработке DSCN2470.JPG: [Errno 1] Operation not permitted
# ❌ Ошибка при обработке DSCN2397.JPG: [Errno 1] Operation not permitted
# ❌ Ошибка при обработке DSCN2458.JPG: [Errno 1] Operation not permitted
# ❌ Ошибка при обработке DSCN2561.JPG: [Errno 1] Operation not permitted
# ❌ Ошибка при обработке DSCN2549.JPG: [Errno 1] Operation not permitted
# ❌ Ошибка при обработке DSCN4809.JPG: [Errno 1] Operation not permitted
# ❌ Ошибка при обработке DSCN4816.JPG: [Errno 1] Operation not permitted
# ❌ Ошибка при обработке DSCN2544.JPG: [Errno 1] Operation not permitted
# ❌ Ошибка при обработке DSCN2580.JPG: [Errno 1] Operation not permitted
# ❌ Ошибка при обработке DSCN2595.JPG: [Errno 1] Operation not permitted
# ❌ Ошибка при обработке DSCN2437.JPG: [Errno 1] Operation not permitted
# ❌ Ошибка при обработке DSCN2522.JPG: [Errno 1] Operation not permitted
# ❌ Ошибка при обработке DSCN2447.JPG: [Errno 1] Operation not permitted
# ❌ Ошибка при обработке DSCN2539.JPG: [Errno 1] Operation not permitted
# ❌ Ошибка при обработке DSCN2460.JPG: [Errno 1] Operation not permitted
# ❌ Ошибка при обработке DSCN2524.JPG: [Errno 1] Operation not permitted
# ❌ Ошибка при обработке DSCN2421.JPG: [Errno 1] Operation not permitted
# ❌ Ошибка при обработке DSCN2557.JPG: [Errno 1] Operation not permitted
# ❌ Ошибка при обработке DSCN2578.JPG: [Errno 1] Operation not permitted
# ❌ Ошибка при обработке DSCN2491.JPG: [Errno 1] Operation not permitted
# ❌ Ошибка при обработке DSCN2443.JPG: [Errno 1] Operation not permitted
# ❌ Ошибка при обработке DSCN2481.JPG: [Errno 1] Operation not permitted
# ❌ Ошибка при обработке DSCN2403.JPG: [Errno 1] Operation not permitted
# ❌ Ошибка при обработке DSCN4810.JPG: [Errno 1] Operation not permitted
# ❌ Ошибка при обработке DSCN2438.JPG: [Errno 1] Operation not permitted
# ❌ Ошибка при обработке DSCN2519.JPG: [Errno 1] Operation not permitted
# ❌ Ошибка при обработке DSCN2485.JPG: [Errno 1] Operation not permitted
# ❌ Ошибка при обработке DSCN2409.JPG: [Errno 1] Operation not permitted
# ❌ Ошибка при обработке DSCN2565.JPG: [Errno 1] Operation not permitted
# ❌ Ошибка при обработке DSCN2534.JPG: [Errno 1] Operation not permitted
# ❌ Ошибка при обработке DSCN2469.JPG: [Errno 1] Operation not permitted
# ❌ Ошибка при обработке DSCN2387.JPG: [Errno 1] Operation not permitted
# ❌ Ошибка при обработке DSCN2598.JPG: [Errno 1] Operation not permitted
# ❌ Ошибка при обработке DSCN2425.JPG: [Errno 1] Operation not permitted
# ❌ Ошибка при обработке DSCN2552.JPG: [Errno 1] Operation not permitted
# ❌ Ошибка при обработке DSCN2536.JPG: [Errno 1] Operation not permitted
# ❌ Ошибка при обработке DSCN2513.JPG: [Errno 1] Operation not permitted
# ❌ Ошибка при обработке DSCN4835.JPG: [Errno 1] Operation not permitted
# ❌ Ошибка при обработке DSCN2562.JPG: [Errno 1] Operation not permitted
# ❌ Ошибка при обработке DSCN2579.JPG: [Errno 1] Operation not permitted
# ❌ Ошибка при обработке DSCN2429.JPG: [Errno 1] Operation not permitted
# ❌ Ошибка при обработке DSCN2412.JPG: [Errno 1] Operation not permitted
# ❌ Ошибка при обработке DSCN4820.JPG: [Errno 1] Operation not permitted
# ❌ Ошибка при обработке DSCN2498.JPG: [Errno 1] Operation not permitted
# ❌ Ошибка при обработке DSCN2515.JPG: [Errno 1] Operation not permitted
# ❌ Ошибка при обработке DSCN2504.JPG: [Errno 1] Operation not permitted
# ❌ Ошибка при обработке DSCN4814.JPG: [Errno 1] Operation not permitted
# ❌ Ошибка при обработке DSCN2404.JPG: [Errno 1] Operation not permitted
# ❌ Ошибка при обработке DSCN2493.JPG: [Errno 1] Operation not permitted
# ❌ Ошибка при обработке DSCN4822.JPG: [Errno 1] Operation not permitted
# 10 Ключ рожковыйнакидной  ¾: 425 изображений
#   Train: 340, Val: 85
# ❌ Ошибка при обработке DSCN2305 (2).JPG: [Errno 1] Operation not permitted
# ❌ Ошибка при обработке DSCN2537.JPG: [Errno 1] Operation not permitted
# ❌ Ошибка при обработке DSCN2351.JPG: [Errno 1] Operation not permitted
# ❌ Ошибка при обработке DSCN2389.JPG: [Errno 1] Operation not permitted
# ❌ Ошибка при обработке DSCN2521.JPG: [Errno 1] Operation not permitted
# ❌ Ошибка при обработке DSCN2334.JPG: [Errno 1] Operation not permitted
# ❌ Ошибка при обработке DSCN4672.JPG: [Errno 1] Operation not permitted
# ❌ Ошибка при обработке DSCN2280.JPG: [Errno 1] Operation not permitted
# ❌ Ошибка при обработке DSCN2444.JPG: [Errno 1] Operation not permitted
# ❌ Ошибка при обработке DSCN2447.JPG: [Errno 1] Operation not permitted
# ❌ Ошибка при обработке DSCN2462.JPG: [Errno 1] Operation not permitted
# ❌ Ошибка при обработке DSCN2407.JPG: [Errno 1] Operation not permitted
# ❌ Ошибка при обработке DSCN2358 (2).JPG: [Errno 1] Operation not permitted
# ❌ Ошибка при обработке DSCN2350 (2).JPG: [Errno 1] Operation not permitted
# ❌ Ошибка при обработке DSCN2425.JPG: [Errno 1] Operation not permitted
# ❌ Ошибка при обработке DSCN2372.JPG: [Errno 1] Operation not permitted
# ❌ Ошибка при обработке DSCN2370 (2).JPG: [Errno 1] Operation not permitted
# ❌ Ошибка при обработке DSCN2459.JPG: [Errno 1] Operation not permitted
# ❌ Ошибка при обработке DSCN2415.JPG: [Errno 1] Operation not permitted
# ❌ Ошибка при обработке DSCN2327.JPG: [Errno 1] Operation not permitted
# ❌ Ошибка при обработке DSCN2341 (2).JPG: [Errno 1] Operation not permitted
# ❌ Ошибка при обработке DSCN2304 (2).JPG: [Errno 1] Operation not permitted
# ❌ Ошибка при обработке DSCN2344 (2).JPG: [Errno 1] Operation not permitted
# ❌ Ошибка при обработке DSCN2487.JPG: [Errno 1] Operation not permitted
# ❌ Ошибка при обработке DSCN2383 (2).JPG: [Errno 1] Operation not permitted
# ❌ Ошибка при обработке DSCN2431.JPG: [Errno 1] Operation not permitted
# ❌ Ошибка при обработке DSCN2470.JPG: [Errno 1] Operation not permitted
# ❌ Ошибка при обработке DSCN4702.JPG: [Errno 1] Operation not permitted
# ❌ Ошибка при обработке DSCN4718.JPG: [Errno 1] Operation not permitted
# ❌ Ошибка при обработке DSCN2366 (2).JPG: [Errno 1] Operation not permitted
# ❌ Ошибка при обработке DSCN4661.JPG: [Errno 1] Operation not permitted
# ❌ Ошибка при обработке DSCN2468.JPG: [Errno 1] Operation not permitted
# ❌ Ошибка при обработке DSCN2373.JPG: [Errno 1] Operation not permitted
# ❌ Ошибка при обработке DSCN2311.JPG: [Errno 1] Operation not permitted
# ❌ Ошибка при обработке DSCN4679.JPG: [Errno 1] Operation not permitted
# ❌ Ошибка при обработке DSCN2395.JPG: [Errno 1] Operation not permitted
# ❌ Ошибка при обработке DSCN2509.JPG: [Errno 1] Operation not permitted
# ❌ Ошибка при обработке DSCN2526.JPG: [Errno 1] Operation not permitted
# ❌ Ошибка при обработке DSCN2322.JPG: [Errno 1] Operation not permitted
# ❌ Ошибка при обработке DSCN2304.JPG: [Errno 1] Operation not permitted
# ❌ Ошибка при обработке DSCN2404.JPG: [Errno 1] Operation not permitted
# ❌ Ошибка при обработке DSCN4655.JPG: [Errno 1] Operation not permitted
# ❌ Ошибка при обработке DSCN2324.JPG: [Errno 1] Operation not permitted
# ❌ Ошибка при обработке DSCN2287.JPG: [Errno 1] Operation not permitted
# ❌ Ошибка при обработке DSCN2346.JPG: [Errno 1] Operation not permitted
# ❌ Ошибка при обработке DSCN2523.JPG: [Errno 1] Operation not permitted
# ❌ Ошибка при обработке DSCN4680.JPG: [Errno 1] Operation not permitted
# ❌ Ошибка при обработке DSCN2357.JPG: [Errno 1] Operation not permitted
# ❌ Ошибка при обработке DSCN2535.JPG: [Errno 1] Operation not permitted
# ❌ Ошибка при обработке DSCN2308.JPG: [Errno 1] Operation not permitted
# ❌ Ошибка при обработке DSCN2378 (2).JPG: [Errno 1] Operation not permitted
# ❌ Ошибка при обработке DSCN2496.JPG: [Errno 1] Operation not permitted
# ❌ Ошибка при обработке DSCN2299.JPG: [Errno 1] Operation not permitted
# ❌ Ошибка при обработке DSCN2538.JPG: [Errno 1] Operation not permitted
# ❌ Ошибка при обработке DSCN2307 (2).JPG: [Errno 1] Operation not permitted
# ❌ Ошибка при обработке DSCN2465.JPG: [Errno 1] Operation not permitted
# ❌ Ошибка при обработке DSCN2312 (2).JPG: [Errno 1] Operation not permitted
# ❌ Ошибка при обработке DSCN4691.JPG: [Errno 1] Operation not permitted
# ❌ Ошибка при обработке DSCN2301.JPG: [Errno 1] Operation not permitted
# ❌ Ошибка при обработке DSCN2324 (2).JPG: [Errno 1] Operation not permitted
# ❌ Ошибка при обработке DSCN2534.JPG: [Errno 1] Operation not permitted
# ❌ Ошибка при обработке DSCN2314.JPG: [Errno 1] Operation not permitted
# ❌ Ошибка при обработке DSCN2376.JPG: [Errno 1] Operation not permitted
# ❌ Ошибка при обработке DSCN2440.JPG: [Errno 1] Operation not permitted
# ❌ Ошибка при обработке DSCN2455.JPG: [Errno 1] Operation not permitted
# ❌ Ошибка при обработке DSCN2375.JPG: [Errno 1] Operation not permitted
# ❌ Ошибка при обработке DSCN2489.JPG: [Errno 1] Operation not permitted
# ❌ Ошибка при обработке DSCN2363 (2).JPG: [Errno 1] Operation not permitted
# ❌ Ошибка при обработке DSCN2442.JPG: [Errno 1] Operation not permitted
# ❌ Ошибка при обработке DSCN2437.JPG: [Errno 1] Operation not permitted
# ❌ Ошибка при обработке DSCN4698.JPG: [Errno 1] Operation not permitted
# ❌ Ошибка при обработке DSCN2374 (2).JPG: [Errno 1] Operation not permitted
# ❌ Ошибка при обработке DSCN2485.JPG: [Errno 1] Operation not permitted
# ❌ Ошибка при обработке DSCN4710.JPG: [Errno 1] Operation not permitted
# ❌ Ошибка при обработке DSCN2532.JPG: [Errno 1] Operation not permitted
# ❌ Ошибка при обработке DSCN2355 (2).JPG: [Errno 1] Operation not permitted
# ❌ Ошибка при обработке DSCN2367 (2).JPG: [Errno 1] Operation not permitted
# ❌ Ошибка при обработке DSCN2453.JPG: [Errno 1] Operation not permitted
# ❌ Ошибка при обработке DSCN2381.JPG: [Errno 1] Operation not permitted
# ❌ Ошибка при обработке DSCN2414.JPG: [Errno 1] Operation not permitted
# ❌ Ошибка при обработке DSCN2311 (2).JPG: [Errno 1] Operation not permitted
# ❌ Ошибка при обработке DSCN2365 (2).JPG: [Errno 1] Operation not permitted
# ❌ Ошибка при обработке DSCN2281.JPG: [Errno 1] Operation not permitted
# ❌ Ошибка при обработке DSCN4700.JPG: [Errno 1] Operation not permitted
# ❌ Ошибка при обработке DSCN2356 (2).JPG: [Errno 1] Operation not permitted
# ❌ Ошибка при обработке DSCN2380.JPG: [Errno 1] Operation not permitted
# ❌ Ошибка при обработке DSCN2541.JPG: [Errno 1] Operation not permitted
# ❌ Ошибка при обработке DSCN2371.JPG: [Errno 1] Operation not permitted
# ❌ Ошибка при обработке DSCN2391.JPG: [Errno 1] Operation not permitted
# ❌ Ошибка при обработке DSCN2392.JPG: [Errno 1] Operation not permitted
# ❌ Ошибка при обработке DSCN2510.JPG: [Errno 1] Operation not permitted
# ❌ Ошибка при обработке DSCN4692.JPG: [Errno 1] Operation not permitted
# ❌ Ошибка при обработке DSCN4689.JPG: [Errno 1] Operation not permitted
# ❌ Ошибка при обработке DSCN2309 (2).JPG: [Errno 1] Operation not permitted
# ❌ Ошибка при обработке DSCN2271.JPG: [Errno 1] Operation not permitted
# ❌ Ошибка при обработке DSCN2388.JPG: [Errno 1] Operation not permitted
# ❌ Ошибка при обработке DSCN2439.JPG: [Errno 1] Operation not permitted
# ❌ Ошибка при обработке DSCN2545.JPG: [Errno 1] Operation not permitted
# ❌ Ошибка при обработке DSCN2520.JPG: [Errno 1] Operation not permitted
# ❌ Ошибка при обработке DSCN2377 (2).JPG: [Errno 1] Operation not permitted
# ❌ Ошибка при обработке DSCN2342 (2).JPG: [Errno 1] Operation not permitted
# ❌ Ошибка при обработке DSCN2345.JPG: [Errno 1] Operation not permitted
# ❌ Ошибка при обработке DSCN2333.JPG: [Errno 1] Operation not permitted
# ❌ Ошибка при обработке DSCN2483.JPG: [Errno 1] Operation not permitted
# ❌ Ошибка при обработке DSCN2325 (2).JPG: [Errno 1] Operation not permitted
# ❌ Ошибка при обработке DSCN4715.JPG: [Errno 1] Operation not permitted
# ❌ Ошибка при обработке DSCN2478.JPG: [Errno 1] Operation not permitted
# ❌ Ошибка при обработке DSCN2386.JPG: [Errno 1] Operation not permitted
# ❌ Ошибка при обработке DSCN2321.JPG: [Errno 1] Operation not permitted
# ❌ Ошибка при обработке DSCN2512.JPG: [Errno 1] Operation not permitted
# ❌ Ошибка при обработке DSCN4699.JPG: [Errno 1] Operation not permitted
# ❌ Ошибка при обработке DSCN2369 (2).JPG: [Errno 1] Operation not permitted
# ❌ Ошибка при обработке DSCN4667.JPG: [Errno 1] Operation not permitted
# ❌ Ошибка при обработке DSCN2282.JPG: [Errno 1] Operation not permitted
# ❌ Ошибка при обработке DSCN2301 (2).JPG: [Errno 1] Operation not permitted
# ❌ Ошибка при обработке DSCN2345 (2).JPG: [Errno 1] Operation not permitted
# ❌ Ошибка при обработке DSCN2418.JPG: [Errno 1] Operation not permitted
# ❌ Ошибка при обработке DSCN2332 (2).JPG: [Errno 1] Operation not permitted
# ❌ Ошибка при обработке DSCN2482.JPG: [Errno 1] Operation not permitted
# ❌ Ошибка при обработке DSCN2326 (2).JPG: [Errno 1] Operation not permitted
# ❌ Ошибка при обработке DSCN2373 (2).JPG: [Errno 1] Operation not permitted
# ❌ Ошибка при обработке DSCN2325.JPG: [Errno 1] Operation not permitted
# ❌ Ошибка при обработке DSCN2441.JPG: [Errno 1] Operation not permitted
# ❌ Ошибка при обработке DSCN4681.JPG: [Errno 1] Operation not permitted
# ❌ Ошибка при обработке DSCN2384.JPG: [Errno 1] Operation not permitted
# ❌ Ошибка при обработке DSCN2504.JPG: [Errno 1] Operation not permitted
# ❌ Ошибка при обработке DSCN2402.JPG: [Errno 1] Operation not permitted
# ❌ Ошибка при обработке DSCN4688.JPG: [Errno 1] Operation not permitted
# ❌ Ошибка при обработке DSCN2398.JPG: [Errno 1] Operation not permitted
# ❌ Ошибка при обработке DSCN4719.JPG: [Errno 1] Operation not permitted
# ❌ Ошибка при обработке DSCN2420.JPG: [Errno 1] Operation not permitted
# ❌ Ошибка при обработке DSCN2382.JPG: [Errno 1] Operation not permitted
# ❌ Ошибка при обработке DSCN2319 (2).JPG: [Errno 1] Operation not permitted
# ❌ Ошибка при обработке DSCN2456.JPG: [Errno 1] Operation not permitted
# ❌ Ошибка при обработке DSCN2340 (2).JPG: [Errno 1] Operation not permitted
# ❌ Ошибка при обработке DSCN2353 (2).JPG: [Errno 1] Operation not permitted
# ❌ Ошибка при обработке DSCN2337.JPG: [Errno 1] Operation not permitted
# ❌ Ошибка при обработке DSCN2285.JPG: [Errno 1] Operation not permitted
# ❌ Ошибка при обработке DSCN2364 (2).JPG: [Errno 1] Operation not permitted
# ❌ Ошибка при обработке DSCN4682.JPG: [Errno 1] Operation not permitted
# ❌ Ошибка при обработке DSCN2448.JPG: [Errno 1] Operation not permitted
# ❌ Ошибка при обработке DSCN2309.JPG: [Errno 1] Operation not permitted
# ❌ Ошибка при обработке DSCN2359.JPG: [Errno 1] Operation not permitted
# ❌ Ошибка при обработке DSCN4708.JPG: [Errno 1] Operation not permitted
# ❌ Ошибка при обработке DSCN2406.JPG: [Errno 1] Operation not permitted
# ❌ Ошибка при обработке DSCN2364.JPG: [Errno 1] Operation not permitted
# ❌ Ошибка при обработке DSCN2303 (2).JPG: [Errno 1] Operation not permitted
# ❌ Ошибка при обработке DSCN2476.JPG: [Errno 1] Operation not permitted
# ❌ Ошибка при обработке DSCN2428.JPG: [Errno 1] Operation not permitted
# ❌ Ошибка при обработке DSCN2451.JPG: [Errno 1] Operation not permitted
# ❌ Ошибка при обработке DSCN2372 (2).JPG: [Errno 1] Operation not permitted
# ❌ Ошибка при обработке DSCN2481.JPG: [Errno 1] Operation not permitted
# ❌ Ошибка при обработке DSCN4678.JPG: [Errno 1] Operation not permitted
# ❌ Ошибка при обработке DSCN2320 (2).JPG: [Errno 1] Operation not permitted
# ❌ Ошибка при обработке DSCN2505.JPG: [Errno 1] Operation not permitted
# ❌ Ошибка при обработке DSCN2424.JPG: [Errno 1] Operation not permitted
# ❌ Ошибка при обработке DSCN2519.JPG: [Errno 1] Operation not permitted
# ❌ Ошибка при обработке DSCN2518.JPG: [Errno 1] Operation not permitted
# ❌ Ошибка при обработке DSCN2293.JPG: [Errno 1] Operation not permitted
# ❌ Ошибка при обработке DSCN2524.JPG: [Errno 1] Operation not permitted
# ❌ Ошибка при обработке DSCN2356.JPG: [Errno 1] Operation not permitted
# ❌ Ошибка при обработке DSCN2494.JPG: [Errno 1] Operation not permitted
# ❌ Ошибка при обработке DSCN2546.JPG: [Errno 1] Operation not permitted
# ❌ Ошибка при обработке DSCN2527.JPG: [Errno 1] Operation not permitted
# ❌ Ошибка при обработке DSCN4701.JPG: [Errno 1] Operation not permitted
# ❌ Ошибка при обработке DSCN2359 (2).JPG: [Errno 1] Operation not permitted
# ❌ Ошибка при обработке DSCN2315 (2).JPG: [Errno 1] Operation not permitted
# ❌ Ошибка при обработке DSCN2335.JPG: [Errno 1] Operation not permitted
# ❌ Ошибка при обработке DSCN2410.JPG: [Errno 1] Operation not permitted
# ❌ Ошибка при обработке DSCN2298.JPG: [Errno 1] Operation not permitted
# ❌ Ошибка при обработке DSCN4714.JPG: [Errno 1] Operation not permitted
# ❌ Ошибка при обработке DSCN2347 (2).JPG: [Errno 1] Operation not permitted
# ❌ Ошибка при обработке DSCN2408.JPG: [Errno 1] Operation not permitted
# ❌ Ошибка при обработке DSCN2283.JPG: [Errno 1] Operation not permitted
# ❌ Ошибка при обработке DSCN2331.JPG: [Errno 1] Operation not permitted
# ❌ Ошибка при обработке DSCN2310 (2).JPG: [Errno 1] Operation not permitted
# ❌ Ошибка при обработке DSCN2393.JPG: [Errno 1] Operation not permitted
# ❌ Ошибка при обработке DSCN2317 (2).JPG: [Errno 1] Operation not permitted
# ❌ Ошибка при обработке DSCN2501.JPG: [Errno 1] Operation not permitted
# ❌ Ошибка при обработке DSCN2328.JPG: [Errno 1] Operation not permitted
# ❌ Ошибка при обработке DSCN2326.JPG: [Errno 1] Operation not permitted
# ❌ Ошибка при обработке DSCN2460.JPG: [Errno 1] Operation not permitted
# ❌ Ошибка при обработке DSCN2529.JPG: [Errno 1] Operation not permitted
# ❌ Ошибка при обработке DSCN2457.JPG: [Errno 1] Operation not permitted
# ❌ Ошибка при обработке DSCN2351 (2).JPG: [Errno 1] Operation not permitted
# ❌ Ошибка при обработке DSCN2290.JPG: [Errno 1] Operation not permitted
# ❌ Ошибка при обработке DSCN2339 (2).JPG: [Errno 1] Operation not permitted
# ❌ Ошибка при обработке DSCN2491.JPG: [Errno 1] Operation not permitted
# ❌ Ошибка при обработке DSCN2382 (2).JPG: [Errno 1] Operation not permitted
# ❌ Ошибка при обработке DSCN4709.JPG: [Errno 1] Operation not permitted
# ❌ Ошибка при обработке DSCN2316 (2).JPG: [Errno 1] Operation not permitted
# ❌ Ошибка при обработке DSCN2318.JPG: [Errno 1] Operation not permitted
# ❌ Ошибка при обработке DSCN4656.JPG: [Errno 1] Operation not permitted
# ❌ Ошибка при обработке DSCN2434.JPG: [Errno 1] Operation not permitted
# ❌ Ошибка при обработке DSCN2397.JPG: [Errno 1] Operation not permitted
# ❌ Ошибка при обработке DSCN2536.JPG: [Errno 1] Operation not permitted
# ❌ Ошибка при обработке DSCN4683.JPG: [Errno 1] Operation not permitted
# ❌ Ошибка при обработке DSCN2279.JPG: [Errno 1] Operation not permitted
# ❌ Ошибка при обработке DSCN2507.JPG: [Errno 1] Operation not permitted
# ❌ Ошибка при обработке DSCN2357 (2).JPG: [Errno 1] Operation not permitted
# ❌ Ошибка при обработке DSCN4707.JPG: [Errno 1] Operation not permitted
# ❌ Ошибка при обработке DSCN4669.JPG: [Errno 1] Operation not permitted
# ❌ Ошибка при обработке DSCN2461.JPG: [Errno 1] Operation not permitted
# ❌ Ошибка при обработке DSCN4704.JPG: [Errno 1] Operation not permitted
# ❌ Ошибка при обработке DSCN2390.JPG: [Errno 1] Operation not permitted
# ❌ Ошибка при обработке DSCN2472.JPG: [Errno 1] Operation not permitted
# ❌ Ошибка при обработке DSCN4670.JPG: [Errno 1] Operation not permitted
# ❌ Ошибка при обработке DSCN2544.JPG: [Errno 1] Operation not permitted
# ❌ Ошибка при обработке DSCN2413.JPG: [Errno 1] Operation not permitted
# ❌ Ошибка при обработке DSCN2497.JPG: [Errno 1] Operation not permitted
# ❌ Ошибка при обработке DSCN2354 (2).JPG: [Errno 1] Operation not permitted
# ❌ Ошибка при обработке DSCN2312.JPG: [Errno 1] Operation not permitted
# ❌ Ошибка при обработке DSCN2381 (2).JPG: [Errno 1] Operation not permitted
# ❌ Ошибка при обработке DSCN4671.JPG: [Errno 1] Operation not permitted
# ❌ Ошибка при обработке DSCN2502.JPG: [Errno 1] Operation not permitted
# ❌ Ошибка при обработке DSCN4666.JPG: [Errno 1] Operation not permitted
# ❌ Ошибка при обработке DSCN2438.JPG: [Errno 1] Operation not permitted
# ❌ Ошибка при обработке DSCN2436.JPG: [Errno 1] Operation not permitted
# ❌ Ошибка при обработке DSCN2360 (2).JPG: [Errno 1] Operation not permitted
# ❌ Ошибка при обработке DSCN2450.JPG: [Errno 1] Operation not permitted
# ❌ Ошибка при обработке DSCN2338.JPG: [Errno 1] Operation not permitted
# ❌ Ошибка при обработке DSCN2517.JPG: [Errno 1] Operation not permitted
# ❌ Ошибка при обработке DSCN2346 (2).JPG: [Errno 1] Operation not permitted
# ❌ Ошибка при обработке DSCN2313.JPG: [Errno 1] Operation not permitted
# ❌ Ошибка при обработке DSCN4696.JPG: [Errno 1] Operation not permitted
# ❌ Ошибка при обработке DSCN2323 (2).JPG: [Errno 1] Operation not permitted
# ❌ Ошибка при обработке DSCN2341.JPG: [Errno 1] Operation not permitted
# ❌ Ошибка при обработке DSCN2339.JPG: [Errno 1] Operation not permitted
# ❌ Ошибка при обработке DSCN2305.JPG: [Errno 1] Operation not permitted
# ❌ Ошибка при обработке DSCN2417.JPG: [Errno 1] Operation not permitted
# ❌ Ошибка при обработке DSCN2314 (2).JPG: [Errno 1] Operation not permitted
# ❌ Ошибка при обработке DSCN2525.JPG: [Errno 1] Operation not permitted
# ❌ Ошибка при обработке DSCN2542.JPG: [Errno 1] Operation not permitted
# ❌ Ошибка при обработке DSCN2513.JPG: [Errno 1] Operation not permitted
# ❌ Ошибка при обработке DSCN2492.JPG: [Errno 1] Operation not permitted
# ❌ Ошибка при обработке DSCN2361 (2).JPG: [Errno 1] Operation not permitted
# ❌ Ошибка при обработке DSCN2405.JPG: [Errno 1] Operation not permitted
# ❌ Ошибка при обработке DSCN2320.JPG: [Errno 1] Operation not permitted
# ❌ Ошибка при обработке DSCN2308 (2).JPG: [Errno 1] Operation not permitted
# ❌ Ошибка при обработке DSCN4674.JPG: [Errno 1] Operation not permitted
# ❌ Ошибка при обработке DSCN2396.JPG: [Errno 1] Operation not permitted
# ❌ Ошибка при обработке DSCN4684.JPG: [Errno 1] Operation not permitted
# ❌ Ошибка при обработке DSCN2533.JPG: [Errno 1] Operation not permitted
# ❌ Ошибка при обработке DSCN2474.JPG: [Errno 1] Operation not permitted
# ❌ Ошибка при обработке DSCN2370.JPG: [Errno 1] Operation not permitted
# ❌ Ошибка при обработке DSCN2334 (2).JPG: [Errno 1] Operation not permitted
# ❌ Ошибка при обработке DSCN2355.JPG: [Errno 1] Operation not permitted
# ❌ Ошибка при обработке DSCN4665.JPG: [Errno 1] Operation not permitted
# ❌ Ошибка при обработке DSCN2432.JPG: [Errno 1] Operation not permitted
# ❌ Ошибка при обработке DSCN2368 (2).JPG: [Errno 1] Operation not permitted
# ❌ Ошибка при обработке DSCN2429.JPG: [Errno 1] Operation not permitted
# ❌ Ошибка при обработке DSCN2347.JPG: [Errno 1] Operation not permitted
# ❌ Ошибка при обработке DSCN2445.JPG: [Errno 1] Operation not permitted
# ❌ Ошибка при обработке DSCN2303.JPG: [Errno 1] Operation not permitted
# ❌ Ошибка при обработке DSCN2329.JPG: [Errno 1] Operation not permitted
# ❌ Ошибка при обработке DSCN2471.JPG: [Errno 1] Operation not permitted
# ❌ Ошибка при обработке DSCN4690.JPG: [Errno 1] Operation not permitted
# ❌ Ошибка при обработке DSCN2446.JPG: [Errno 1] Operation not permitted
# ❌ Ошибка при обработке DSCN2352.JPG: [Errno 1] Operation not permitted
# ❌ Ошибка при обработке DSCN2342.JPG: [Errno 1] Operation not permitted
# ❌ Ошибка при обработке DSCN4687.JPG: [Errno 1] Operation not permitted
# ❌ Ошибка при обработке DSCN2296.JPG: [Errno 1] Operation not permitted
# ❌ Ошибка при обработке DSCN2349.JPG: [Errno 1] Operation not permitted
# ❌ Ошибка при обработке DSCN2385.JPG: [Errno 1] Operation not permitted
# ❌ Ошибка при обработке DSCN4675.JPG: [Errno 1] Operation not permitted
# ❌ Ошибка при обработке DSCN2495.JPG: [Errno 1] Operation not permitted
# ❌ Ошибка при обработке DSCN2435.JPG: [Errno 1] Operation not permitted
# ❌ Ошибка при обработке DSCN2379.JPG: [Errno 1] Operation not permitted
# ❌ Ошибка при обработке DSCN4685.JPG: [Errno 1] Operation not permitted
# ❌ Ошибка при обработке DSCN2318 (2).JPG: [Errno 1] Operation not permitted
# ❌ Ошибка при обработке DSCN2458.JPG: [Errno 1] Operation not permitted
# ❌ Ошибка при обработке DSCN2486.JPG: [Errno 1] Operation not permitted
# ❌ Ошибка при обработке DSCN2322 (2).JPG: [Errno 1] Operation not permitted
# ❌ Ошибка при обработке DSCN2484.JPG: [Errno 1] Operation not permitted
# ❌ Ошибка при обработке DSCN4657.JPG: [Errno 1] Operation not permitted
# ❌ Ошибка при обработке DSCN2297.JPG: [Errno 1] Operation not permitted
# ❌ Ошибка при обработке DSCN2499.JPG: [Errno 1] Operation not permitted
# ❌ Ошибка при обработке DSCN2366.JPG: [Errno 1] Operation not permitted
# ❌ Ошибка при обработке DSCN2443.JPG: [Errno 1] Operation not permitted
# ❌ Ошибка при обработке DSCN2515.JPG: [Errno 1] Operation not permitted
# ❌ Ошибка при обработке DSCN2490.JPG: [Errno 1] Operation not permitted
# ❌ Ошибка при обработке DSCN2306 (2).JPG: [Errno 1] Operation not permitted
# ❌ Ошибка при обработке DSCN2306.JPG: [Errno 1] Operation not permitted
# ❌ Ошибка при обработке DSCN4703.JPG: [Errno 1] Operation not permitted
# ❌ Ошибка при обработке DSCN2315.JPG: [Errno 1] Operation not permitted
# ❌ Ошибка при обработке DSCN2371 (2).JPG: [Errno 1] Operation not permitted
# ❌ Ошибка при обработке DSCN2291.JPG: [Errno 1] Operation not permitted
# ❌ Ошибка при обработке DSCN2543.JPG: [Errno 1] Operation not permitted
# ❌ Ошибка при обработке DSCN2286.JPG: [Errno 1] Operation not permitted
# ❌ Ошибка при обработке DSCN2503.JPG: [Errno 1] Operation not permitted
# ❌ Ошибка при обработке DSCN2379 (2).JPG: [Errno 1] Operation not permitted
# ❌ Ошибка при обработке DSCN2384 (2).JPG: [Errno 1] Operation not permitted
# ❌ Ошибка при обработке DSCN2340.JPG: [Errno 1] Operation not permitted
# ❌ Ошибка при обработке DSCN2387.JPG: [Errno 1] Operation not permitted
# ❌ Ошибка при обработке DSCN4659.JPG: [Errno 1] Operation not permitted
# ❌ Ошибка при обработке DSCN4713.JPG: [Errno 1] Operation not permitted
# ❌ Ошибка при обработке DSCN2327 (2).JPG: [Errno 1] Operation not permitted
# ❌ Ошибка при обработке DSCN2354.JPG: [Errno 1] Operation not permitted
# ❌ Ошибка при обработке DSCN2383.JPG: [Errno 1] Operation not permitted
# ❌ Ошибка при обработке DSCN2353.JPG: [Errno 1] Operation not permitted
# ❌ Ошибка при обработке DSCN2522.JPG: [Errno 1] Operation not permitted
# ❌ Ошибка при обработке DSCN2352 (2).JPG: [Errno 1] Operation not permitted
# ❌ Ошибка при обработке DSCN2508.JPG: [Errno 1] Operation not permitted
# ❌ Ошибка при обработке DSCN2361.JPG: [Errno 1] Operation not permitted
# ❌ Ошибка при обработке DSCN2338 (2).JPG: [Errno 1] Operation not permitted
# ❌ Ошибка при обработке DSCN4662.JPG: [Errno 1] Operation not permitted
# ❌ Ошибка при обработке DSCN2477.JPG: [Errno 1] Operation not permitted
# ❌ Ошибка при обработке DSCN2295.JPG: [Errno 1] Operation not permitted
# ❌ Ошибка при обработке DSCN2399.JPG: [Errno 1] Operation not permitted
# ❌ Ошибка при обработке DSCN2332.JPG: [Errno 1] Operation not permitted
# ❌ Ошибка при обработке DSCN2516.JPG: [Errno 1] Operation not permitted
# ❌ Ошибка при обработке DSCN2547.JPG: [Errno 1] Operation not permitted
# ❌ Ошибка при обработке DSCN2427.JPG: [Errno 1] Operation not permitted
# ❌ Ошибка при обработке DSCN2498.JPG: [Errno 1] Operation not permitted
# ❌ Ошибка при обработке DSCN2369.JPG: [Errno 1] Operation not permitted
# ❌ Ошибка при обработке DSCN2449.JPG: [Errno 1] Operation not permitted
# ❌ Ошибка при обработке DSCN2401.JPG: [Errno 1] Operation not permitted
# ❌ Ошибка при обработке DSCN4693.JPG: [Errno 1] Operation not permitted
# ❌ Ошибка при обработке DSCN2378.JPG: [Errno 1] Operation not permitted
# ❌ Ошибка при обработке DSCN2454.JPG: [Errno 1] Operation not permitted
# ❌ Ошибка при обработке DSCN2467.JPG: [Errno 1] Operation not permitted
# ❌ Ошибка при обработке DSCN2466.JPG: [Errno 1] Operation not permitted
# ❌ Ошибка при обработке DSCN4694.JPG: [Errno 1] Operation not permitted
# ❌ Ошибка при обработке DSCN2313 (2).JPG: [Errno 1] Operation not permitted
# ❌ Ошибка при обработке DSCN2336 (2).JPG: [Errno 1] Operation not permitted
# ❌ Ошибка при обработке DSCN2331 (2).JPG: [Errno 1] Operation not permitted
# ❌ Ошибка при обработке DSCN2528.JPG: [Errno 1] Operation not permitted
# ❌ Ошибка при обработке DSCN2374.JPG: [Errno 1] Operation not permitted
# ❌ Ошибка при обработке DSCN4664.JPG: [Errno 1] Operation not permitted
# ❌ Ошибка при обработке DSCN4660.JPG: [Errno 1] Operation not permitted
# ❌ Ошибка при обработке DSCN2284.JPG: [Errno 1] Operation not permitted
# ❌ Ошибка при обработке DSCN2480.JPG: [Errno 1] Operation not permitted
# ❌ Ошибка при обработке DSCN4705.JPG: [Errno 1] Operation not permitted
# ❌ Ошибка при обработке DSCN2409.JPG: [Errno 1] Operation not permitted
# ❌ Ошибка при обработке DSCN2412.JPG: [Errno 1] Operation not permitted
# ❌ Ошибка при обработке DSCN2360.JPG: [Errno 1] Operation not permitted
# ❌ Ошибка при обработке DSCN2377.JPG: [Errno 1] Operation not permitted
# ❌ Ошибка при обработке DSCN2506.JPG: [Errno 1] Operation not permitted
# ❌ Ошибка при обработке DSCN2479.JPG: [Errno 1] Operation not permitted
# ❌ Ошибка при обработке DSCN2411.JPG: [Errno 1] Operation not permitted
# ❌ Ошибка при обработке DSCN4677.JPG: [Errno 1] Operation not permitted
# ❌ Ошибка при обработке DSCN4668.JPG: [Errno 1] Operation not permitted
# ❌ Ошибка при обработке DSCN2336.JPG: [Errno 1] Operation not permitted
# ❌ Ошибка при обработке DSCN2321 (2).JPG: [Errno 1] Operation not permitted
# ❌ Ошибка при обработке DSCN2488.JPG: [Errno 1] Operation not permitted
# ❌ Ошибка при обработке DSCN2302 (2).JPG: [Errno 1] Operation not permitted
# ❌ Ошибка при обработке DSCN2300.JPG: [Errno 1] Operation not permitted
# ❌ Ошибка при обработке DSCN2473.JPG: [Errno 1] Operation not permitted
# ❌ Ошибка при обработке DSCN2294.JPG: [Errno 1] Operation not permitted
# ❌ Ошибка при обработке DSCN2475.JPG: [Errno 1] Operation not permitted
# ❌ Ошибка при обработке DSCN2469.JPG: [Errno 1] Operation not permitted
# ❌ Ошибка при обработке DSCN2278.JPG: [Errno 1] Operation not permitted
# ❌ Ошибка при обработке DSCN2403.JPG: [Errno 1] Operation not permitted
# ❌ Ошибка при обработке DSCN2348.JPG: [Errno 1] Operation not permitted
# ❌ Ошибка при обработке DSCN2400.JPG: [Errno 1] Operation not permitted
# ❌ Ошибка при обработке DSCN2416.JPG: [Errno 1] Operation not permitted
# ❌ Ошибка при обработке DSCN2511.JPG: [Errno 1] Operation not permitted
# ❌ Ошибка при обработке DSCN4654.JPG: [Errno 1] Operation not permitted
# ❌ Ошибка при обработке DSCN2317.JPG: [Errno 1] Operation not permitted
# ❌ Ошибка при обработке DSCN2362 (2).JPG: [Errno 1] Operation not permitted
# ❌ Ошибка при обработке DSCN2316.JPG: [Errno 1] Operation not permitted
# ❌ Ошибка при обработке DSCN2310.JPG: [Errno 1] Operation not permitted
# ❌ Ошибка при обработке DSCN2292.JPG: [Errno 1] Operation not permitted
# ❌ Ошибка при обработке DSCN2329 (2).JPG: [Errno 1] Operation not permitted
# ❌ Ошибка при обработке DSCN2276.JPG: [Errno 1] Operation not permitted
# ❌ Ошибка при обработке DSCN2464.JPG: [Errno 1] Operation not permitted
# ❌ Ошибка при обработке DSCN2343.JPG: [Errno 1] Operation not permitted
# ❌ Ошибка при обработке DSCN2350.JPG: [Errno 1] Operation not permitted
# ❌ Ошибка при обработке DSCN2394.JPG: [Errno 1] Operation not permitted
# ❌ Ошибка при обработке DSCN4706.JPG: [Errno 1] Operation not permitted
# ❌ Ошибка при обработке DSCN2289.JPG: [Errno 1] Operation not permitted
# ❌ Ошибка при обработке DSCN2367.JPG: [Errno 1] Operation not permitted
# ❌ Ошибка при обработке DSCN2539.JPG: [Errno 1] Operation not permitted
# ❌ Ошибка при обработке DSCN2307.JPG: [Errno 1] Operation not permitted
# ❌ Ошибка при обработке DSCN4712.JPG: [Errno 1] Operation not permitted
# ❌ Ошибка при обработке DSCN2500.JPG: [Errno 1] Operation not permitted
# ❌ Ошибка при обработке DSCN2422.JPG: [Errno 1] Operation not permitted
# ❌ Ошибка при обработке DSCN4697.JPG: [Errno 1] Operation not permitted
# ❌ Ошибка при обработке DSCN2337 (2).JPG: [Errno 1] Operation not permitted
# ❌ Ошибка при обработке DSCN2333 (2).JPG: [Errno 1] Operation not permitted
# ❌ Ошибка при обработке DSCN2376 (2).JPG: [Errno 1] Operation not permitted
# ❌ Ошибка при обработке DSCN2452.JPG: [Errno 1] Operation not permitted
# ❌ Ошибка при обработке DSCN4695.JPG: [Errno 1] Operation not permitted
# ❌ Ошибка при обработке DSCN2493.JPG: [Errno 1] Operation not permitted
# ❌ Ошибка при обработке DSCN2375 (2).JPG: [Errno 1] Operation not permitted
# ❌ Ошибка при обработке DSCN2319.JPG: [Errno 1] Operation not permitted
# ❌ Ошибка при обработке DSCN4673.JPG: [Errno 1] Operation not permitted
# ❌ Ошибка при обработке DSCN2423.JPG: [Errno 1] Operation not permitted
# ❌ Ошибка при обработке DSCN4658.JPG: [Errno 1] Operation not permitted
# ❌ Ошибка при обработке DSCN2514.JPG: [Errno 1] Operation not permitted
# ❌ Ошибка при обработке DSCN2335 (2).JPG: [Errno 1] Operation not permitted
# ❌ Ошибка при обработке DSCN2463.JPG: [Errno 1] Operation not permitted
# ❌ Ошибка при обработке DSCN2433.JPG: [Errno 1] Operation not permitted
# ❌ Ошибка при обработке DSCN2426.JPG: [Errno 1] Operation not permitted
# ❌ Ошибка при обработке DSCN4720.JPG: [Errno 1] Operation not permitted
# ❌ Ошибка при обработке DSCN2548.JPG: [Errno 1] Operation not permitted
# ❌ Ошибка при обработке DSCN2328 (2).JPG: [Errno 1] Operation not permitted
# ❌ Ошибка при обработке DSCN2363.JPG: [Errno 1] Operation not permitted
# ❌ Ошибка при обработке DSCN2344.JPG: [Errno 1] Operation not permitted
# ❌ Ошибка при обработке DSCN2330 (2).JPG: [Errno 1] Operation not permitted
# ❌ Ошибка при обработке DSCN2358.JPG: [Errno 1] Operation not permitted
# ❌ Ошибка при обработке DSCN2343 (2).JPG: [Errno 1] Operation not permitted
# ❌ Ошибка при обработке DSCN2288.JPG: [Errno 1] Operation not permitted
# ❌ Ошибка при обработке DSCN4663.JPG: [Errno 1] Operation not permitted
# ❌ Ошибка при обработке DSCN2323.JPG: [Errno 1] Operation not permitted
# ❌ Ошибка при обработке DSCN4686.JPG: [Errno 1] Operation not permitted
# ❌ Ошибка при обработке DSCN2419.JPG: [Errno 1] Operation not permitted
# ❌ Ошибка при обработке DSCN2368.JPG: [Errno 1] Operation not permitted
# ❌ Ошибка при обработке DSCN2530.JPG: [Errno 1] Operation not permitted
# ❌ Ошибка при обработке DSCN2531.JPG: [Errno 1] Operation not permitted
# ...
# ❌ Ошибка при обработке DSCN1595.JPG: [Errno 1] Operation not permitted
# ❌ Ошибка при обработке DSCN4885.JPG: [Errno 1] Operation not permitted
# ❌ Ошибка при обработке DSCN1426.JPG: [Errno 1] Operation not permitted
# ❌ Ошибка при обработке DSCN4847.JPG: [Errno 1] Operation not permitted
# ❌ Ошибка при обработке DSCN1441.JPG: [Errno 1] Operation not permitted
# ❌ Ошибка при обработке DSCN4875.JPG: [Errno 1] Operation not permitted
# ❌ Ошибка при обработке DSCN1615.JPG: [Errno 1] Operation not permitted
# ❌ Ошибка при обработке DSCN1582.JPG: [Errno 1] Operation not permitted
# ❌ Ошибка при обработке DSCN4870.JPG: [Errno 1] Operation not permitted
# ❌ Ошибка при обработке DSCN1475.JPG: [Errno 1] Operation not permitted
# ❌ Ошибка при обработке DSCN4887.JPG: [Errno 1] Operation not permitted
# ❌ Ошибка при обработке DSCN1412.JPG: [Errno 1] Operation not permitted
# ❌ Ошибка при обработке DSCN1585.JPG: [Errno 1] Operation not permitted
# ❌ Ошибка при обработке DSCN1457.JPG: [Errno 1] Operation not permitted
# ❌ Ошибка при обработке DSCN4860.JPG: [Errno 1] Operation not permitted
# ❌ Ошибка при обработке DSCN1413.JPG: [Errno 1] Operation not permitted
# ❌ Ошибка при обработке DSCN1466.JPG: [Errno 1] Operation not permitted
# ❌ Ошибка при обработке DSCN1608.JPG: [Errno 1] Operation not permitted
# ❌ Ошибка при обработке DSCN1607.JPG: [Errno 1] Operation not permitted
# ❌ Ошибка при обработке DSCN1614.JPG: [Errno 1] Operation not permitted
# ❌ Ошибка при обработке DSCN1398.JPG: [Errno 1] Operation not permitted
# ❌ Ошибка при обработке DSCN1570.JPG: [Errno 1] Operation not permitted
# ❌ Ошибка при обработке DSCN4854.JPG: [Errno 1] Operation not permitted
# ❌ Ошибка при обработке DSCN1535.JPG: [Errno 1] Operation not permitted
# ❌ Ошибка при обработке DSCN1424.JPG: [Errno 1] Operation not permitted
# ❌ Ошибка при обработке DSCN1613.JPG: [Errno 1] Operation not permitted
# ❌ Ошибка при обработке DSCN1405.JPG: [Errno 1] Operation not permitted
# ❌ Ошибка при обработке DSCN1594.JPG: [Errno 1] Operation not permitted
# ❌ Ошибка при обработке DSCN1517.JPG: [Errno 1] Operation not permitted
# ❌ Ошибка при обработке DSCN1550.JPG: [Errno 1] Operation not permitted
# ❌ Ошибка при обработке DSCN4864.JPG: [Errno 1] Operation not permitted
# ❌ Ошибка при обработке DSCN1576.JPG: [Errno 1] Operation not permitted
# ❌ Ошибка при обработке DSCN4874.JPG: [Errno 1] Operation not permitted
# ❌ Ошибка при обработке DSCN1478.JPG: [Errno 1] Operation not permitted
# ❌ Ошибка при обработке DSCN1488.JPG: [Errno 1] Operation not permitted
# ❌ Ошибка при обработке DSCN4850.JPG: [Errno 1] Operation not permitted
# ❌ Ошибка при обработке DSCN1419.JPG: [Errno 1] Operation not permitted
# ❌ Ошибка при обработке DSCN4863.JPG: [Errno 1] Operation not permitted
# ❌ Ошибка при обработке DSCN1569.JPG: [Errno 1] Operation not permitted
# ❌ Ошибка при обработке DSCN1624.JPG: [Errno 1] Operation not permitted
# ❌ Ошибка при обработке DSCN1485.JPG: [Errno 1] Operation not permitted
# ❌ Ошибка при обработке DSCN1506.JPG: [Errno 1] Operation not permitted
# ❌ Ошибка при обработке DSCN1400.JPG: [Errno 1] Operation not permitted
# ❌ Ошибка при обработке DSCN1533.JPG: [Errno 1] Operation not permitted
# ❌ Ошибка при обработке DSCN1425.JPG: [Errno 1] Operation not permitted
# ❌ Ошибка при обработке DSCN1501.JPG: [Errno 1] Operation not permitted
# ❌ Ошибка при обработке DSCN1500.JPG: [Errno 1] Operation not permitted
# ❌ Ошибка при обработке DSCN1462.JPG: [Errno 1] Operation not permitted
# ❌ Ошибка при обработке DSCN1474.JPG: [Errno 1] Operation not permitted
# ❌ Ошибка при обработке DSCN1469.JPG: [Errno 1] Operation not permitted
# ❌ Ошибка при обработке DSCN1490.JPG: [Errno 1] Operation not permitted
# ❌ Ошибка при обработке DSCN1578.JPG: [Errno 1] Operation not permitted
# ❌ Ошибка при обработке DSCN1634.JPG: [Errno 1] Operation not permitted
# ❌ Ошибка при обработке DSCN1629.JPG: [Errno 1] Operation not permitted
# ❌ Ошибка при обработке DSCN1609.JPG: [Errno 1] Operation not permitted
# ❌ Ошибка при обработке DSCN1514.JPG: [Errno 1] Operation not permitted
# ❌ Ошибка при обработке DSCN1393.JPG: [Errno 1] Operation not permitted
# ❌ Ошибка при обработке DSCN1527.JPG: [Errno 1] Operation not permitted
# ❌ Ошибка при обработке DSCN1444.JPG: [Errno 1] Operation not permitted
# ❌ Ошибка при обработке DSCN1558.JPG: [Errno 1] Operation not permitted
# ❌ Ошибка при обработке DSCN1422.JPG: [Errno 1] Operation not permitted
# ❌ Ошибка при обработке DSCN1589.JPG: [Errno 1] Operation not permitted
# ❌ Ошибка при обработке DSCN1446.JPG: [Errno 1] Operation not permitted
# ❌ Ошибка при обработке DSCN1420.JPG: [Errno 1] Operation not permitted
# ❌ Ошибка при обработке DSCN1605.JPG: [Errno 1] Operation not permitted
# ❌ Ошибка при обработке DSCN1573.JPG: [Errno 1] Operation not permitted
# ❌ Ошибка при обработке DSCN1522.JPG: [Errno 1] Operation not permitted
# ❌ Ошибка при обработке DSCN4884.JPG: [Errno 1] Operation not permitted
# ❌ Ошибка при обработке DSCN1597.JPG: [Errno 1] Operation not permitted
# ❌ Ошибка при обработке DSCN1468.JPG: [Errno 1] Operation not permitted
# ❌ Ошибка при обработке DSCN4836.JPG: [Errno 1] Operation not permitted
# ❌ Ошибка при обработке DSCN1452.JPG: [Errno 1] Operation not permitted
# ❌ Ошибка при обработке DSCN1636.JPG: [Errno 1] Operation not permitted
# ❌ Ошибка при обработке DSCN1463.JPG: [Errno 1] Operation not permitted
# ❌ Ошибка при обработке DSCN1610.JPG: [Errno 1] Operation not permitted
# ❌ Ошибка при обработке DSCN4862.JPG: [Errno 1] Operation not permitted
# ❌ Ошибка при обработке DSCN1494.JPG: [Errno 1] Operation not permitted
# ❌ Ошибка при обработке DSCN1415.JPG: [Errno 1] Operation not permitted
# ❌ Ошибка при обработке DSCN1623.JPG: [Errno 1] Operation not permitted
# ❌ Ошибка при обработке DSCN1556.JPG: [Errno 1] Operation not permitted
# ❌ Ошибка при обработке DSCN1491.JPG: [Errno 1] Operation not permitted
# ❌ Ошибка при обработке DSCN1470.JPG: [Errno 1] Operation not permitted
# ❌ Ошибка при обработке DSCN1440.JPG: [Errno 1] Operation not permitted
# ❌ Ошибка при обработке DSCN1562.JPG: [Errno 1] Operation not permitted
# ❌ Ошибка при обработке DSCN1554.JPG: [Errno 1] Operation not permitted
# ❌ Ошибка при обработке DSCN1641.JPG: [Errno 1] Operation not permitted
# ❌ Ошибка при обработке DSCN1611.JPG: [Errno 1] Operation not permitted
# ❌ Ошибка при обработке DSCN1619.JPG: [Errno 1] Operation not permitted
# ❌ Ошибка при обработке DSCN1593.JPG: [Errno 1] Operation not permitted
# ❌ Ошибка при обработке DSCN1432.JPG: [Errno 1] Operation not permitted
# ❌ Ошибка при обработке DSCN4879.JPG: [Errno 1] Operation not permitted
# ❌ Ошибка при обработке DSCN1509.JPG: [Errno 1] Operation not permitted
# ❌ Ошибка при обработке DSCN1528.JPG: [Errno 1] Operation not permitted
# ❌ Ошибка при обработке DSCN1414.JPG: [Errno 1] Operation not permitted
# ❌ Ошибка при обработке DSCN1632.JPG: [Errno 1] Operation not permitted
# ❌ Ошибка при обработке DSCN1541.JPG: [Errno 1] Operation not permitted
# ❌ Ошибка при обработке DSCN1481.JPG: [Errno 1] Operation not permitted
# ❌ Ошибка при обработке DSCN1520.JPG: [Errno 1] Operation not permitted
# ❌ Ошибка при обработке DSCN1606.JPG: [Errno 1] Operation not permitted
# ❌ Ошибка при обработке DSCN4881.JPG: [Errno 1] Operation not permitted
# ❌ Ошибка при обработке DSCN1460.JPG: [Errno 1] Operation not permitted
# ❌ Ошибка при обработке DSCN1553.JPG: [Errno 1] Operation not permitted
# ❌ Ошибка при обработке DSCN4852.JPG: [Errno 1] Operation not permitted
# ❌ Ошибка при обработке DSCN4846.JPG: [Errno 1] Operation not permitted
# ❌ Ошибка при обработке DSCN1394.JPG: [Errno 1] Operation not permitted
# ❌ Ошибка при обработке DSCN1580.JPG: [Errno 1] Operation not permitted
# ❌ Ошибка при обработке DSCN4858.JPG: [Errno 1] Operation not permitted
# ❌ Ошибка при обработке DSCN1561.JPG: [Errno 1] Operation not permitted
# ❌ Ошибка при обработке DSCN4886.JPG: [Errno 1] Operation not permitted
# ❌ Ошибка при обработке DSCN1544.JPG: [Errno 1] Operation not permitted
# ❌ Ошибка при обработке DSCN1401.JPG: [Errno 1] Operation not permitted
# ❌ Ошибка при обработке DSCN1472.JPG: [Errno 1] Operation not permitted
# ❌ Ошибка при обработке DSCN1603.JPG: [Errno 1] Operation not permitted
# ❌ Ошибка при обработке DSCN1515.JPG: [Errno 1] Operation not permitted
# ❌ Ошибка при обработке DSCN1604.JPG: [Errno 1] Operation not permitted
# ❌ Ошибка при обработке DSCN1508.JPG: [Errno 1] Operation not permitted
# ❌ Ошибка при обработке DSCN1616.JPG: [Errno 1] Operation not permitted
# ❌ Ошибка при обработке DSCN1434.JPG: [Errno 1] Operation not permitted
# ❌ Ошибка при обработке DSCN1448.JPG: [Errno 1] Operation not permitted
# ❌ Ошибка при обработке DSCN1397.JPG: [Errno 1] Operation not permitted
# ❌ Ошибка при обработке DSCN1427.JPG: [Errno 1] Operation not permitted
# ❌ Ошибка при обработке DSCN1592.JPG: [Errno 1] Operation not permitted
# ❌ Ошибка при обработке DSCN1635.JPG: [Errno 1] Operation not permitted
# ❌ Ошибка при обработке DSCN1552.JPG: [Errno 1] Operation not permitted
# ❌ Ошибка при обработке DSCN1568.JPG: [Errno 1] Operation not permitted
# ❌ Ошибка при обработке DSCN1586.JPG: [Errno 1] Operation not permitted
# ❌ Ошибка при обработке DSCN4837.JPG: [Errno 1] Operation not permitted
# ❌ Ошибка при обработке DSCN1574.JPG: [Errno 1] Operation not permitted
# ❌ Ошибка при обработке DSCN1502.JPG: [Errno 1] Operation not permitted
# ❌ Ошибка при обработке DSCN1622.JPG: [Errno 1] Operation not permitted
# ❌ Ошибка при обработке DSCN1526.JPG: [Errno 1] Operation not permitted
# ❌ Ошибка при обработке DSCN1532.JPG: [Errno 1] Operation not permitted
# ❌ Ошибка при обработке DSCN1497.JPG: [Errno 1] Operation not permitted
# ❌ Ошибка при обработке DSCN1621.JPG: [Errno 1] Operation not permitted
# ❌ Ошибка при обработке DSCN4883.JPG: [Errno 1] Operation not permitted
# ❌ Ошибка при обработке DSCN1454.JPG: [Errno 1] Operation not permitted
# ❌ Ошибка при обработке DSCN1537.JPG: [Errno 1] Operation not permitted
# ❌ Ошибка при обработке DSCN1436.JPG: [Errno 1] Operation not permitted
# ❌ Ошибка при обработке DSCN1612.JPG: [Errno 1] Operation not permitted
# ❌ Ошибка при обработке DSCN4849.JPG: [Errno 1] Operation not permitted
# ❌ Ошибка при обработке DSCN1438.JPG: [Errno 1] Operation not permitted
# ❌ Ошибка при обработке DSCN1587.JPG: [Errno 1] Operation not permitted
# ❌ Ошибка при обработке DSCN1559.JPG: [Errno 1] Operation not permitted
# ❌ Ошибка при обработке DSCN1540.JPG: [Errno 1] Operation not permitted
# ❌ Ошибка при обработке DSCN4851.JPG: [Errno 1] Operation not permitted
# ❌ Ошибка при обработке DSCN1402.JPG: [Errno 1] Operation not permitted
# ❌ Ошибка при обработке DSCN1584.JPG: [Errno 1] Operation not permitted
# ❌ Ошибка при обработке DSCN4848.JPG: [Errno 1] Operation not permitted
# ❌ Ошибка при обработке DSCN1625.JPG: [Errno 1] Operation not permitted
# ❌ Ошибка при обработке DSCN1406.JPG: [Errno 1] Operation not permitted
# ❌ Ошибка при обработке DSCN1542.JPG: [Errno 1] Operation not permitted
# ❌ Ошибка при обработке DSCN1557.JPG: [Errno 1] Operation not permitted
# ❌ Ошибка при обработке DSCN1639.JPG: [Errno 1] Operation not permitted
# ❌ Ошибка при обработке DSCN1499.JPG: [Errno 1] Operation not permitted
# ❌ Ошибка при обработке DSCN4878.JPG: [Errno 1] Operation not permitted
# ❌ Ошибка при обработке DSCN1563.JPG: [Errno 1] Operation not permitted
# ❌ Ошибка при обработке DSCN1565.JPG: [Errno 1] Operation not permitted
# ❌ Ошибка при обработке DSCN1464.JPG: [Errno 1] Operation not permitted
# ❌ Ошибка при обработке DSCN1404.JPG: [Errno 1] Operation not permitted
# ❌ Ошибка при обработке DSCN1620.JPG: [Errno 1] Operation not permitted
# ❌ Ошибка при обработке DSCN4839.JPG: [Errno 1] Operation not permitted
# ❌ Ошибка при обработке DSCN1627.JPG: [Errno 1] Operation not permitted
# ❌ Ошибка при обработке DSCN1539.JPG: [Errno 1] Operation not permitted
# ❌ Ошибка при обработке DSCN1458.JPG: [Errno 1] Operation not permitted
# ❌ Ошибка при обработке DSCN4867.JPG: [Errno 1] Operation not permitted
# ❌ Ошибка при обработке DSCN4857.JPG: [Errno 1] Operation not permitted
# ❌ Ошибка при обработке DSCN1513.JPG: [Errno 1] Operation not permitted
# ❌ Ошибка при обработке DSCN4876.JPG: [Errno 1] Operation not permitted
# ❌ Ошибка при обработке DSCN1417.JPG: [Errno 1] Operation not permitted
# ❌ Ошибка при обработке DSCN1443.JPG: [Errno 1] Operation not permitted
# ❌ Ошибка при обработке DSCN1564.JPG: [Errno 1] Operation not permitted
# ❌ Ошибка при обработке DSCN1521.JPG: [Errno 1] Operation not permitted
# ❌ Ошибка при обработке DSCN1529.JPG: [Errno 1] Operation not permitted
# ❌ Ошибка при обработке DSCN1504.JPG: [Errno 1] Operation not permitted
# ❌ Ошибка при обработке DSCN4872.JPG: [Errno 1] Operation not permitted
# ❌ Ошибка при обработке DSCN1628.JPG: [Errno 1] Operation not permitted
# ❌ Ошибка при обработке DSCN1465.JPG: [Errno 1] Operation not permitted
# ❌ Ошибка при обработке DSCN1511.JPG: [Errno 1] Operation not permitted
# ❌ Ошибка при обработке DSCN4869.JPG: [Errno 1] Operation not permitted
# ❌ Ошибка при обработке DSCN1467.JPG: [Errno 1] Operation not permitted
# ❌ Ошибка при обработке DSCN1547.JPG: [Errno 1] Operation not permitted
# ❌ Ошибка при обработке DSCN1408.JPG: [Errno 1] Operation not permitted
# ❌ Ошибка при обработке DSCN4868.JPG: [Errno 1] Operation not permitted
# ❌ Ошибка при обработке DSCN1431.JPG: [Errno 1] Operation not permitted
# 3 Отвертка на смещенный крест: 275 изображений
#   Train: 220, Val: 55
# ❌ Ошибка при обработке DSCN1717.JPG: [Errno 1] Operation not permitted
# ❌ Ошибка при обработке DSCN1859.JPG: [Errno 1] Operation not permitted
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[10], line 70
#      67         traceback.print_exc()
#      69 if __name__ == "__main__":
# ---> 70     main()
#
# Cell In[10], line 18, in main()
#      16 # Шаг 1: Подготовка датасета
#      17 print("\n📁 ШАГ 1: Подготовка датасета...")
# ---> 18 classes = prepare_yolo_dataset(dataset_path, output_dir)
#      20 # Шаг 2: Создание конфигурации
#      21 print("\n⚙️  ШАГ 2: Создание конфигурации...")
#
# Cell In[4], line 38, in prepare_yolo_dataset(dataset_path, output_dir)
#      35         f.write(f"{class_name}\n")
#      37 # Обрабатываем данные
# ---> 38 process_single_tools(dataset_path, output_dir, tools_folders)
#      39 process_group_photos(dataset_path, output_dir, group_folders)
#      41 # Проверяем результат
#
# Cell In[3], line 33, in process_single_tools(dataset_path, output_dir, classes)
#      30     total_images += len(images)
#      32     # Копируем изображения и создаем аннотации
# ---> 33     copy_images_with_annotations(class_path, output_dir, class_idx, 'train', train_imgs,
#      34                                bbox_coords=(0.5, 0.5, 1.0, 1.0))  # Весь изображение
#      35     copy_images_with_annotations(class_path, output_dir, class_idx, 'val', val_imgs,
#      36                                bbox_coords=(0.5, 0.5, 1.0, 1.0))
#      38 print(f"✓ Обработано отдельных инструментов: {total_images} изображений")
#
# Cell In[2], line 8, in copy_images_with_annotations(src_dir, output_dir, class_idx, split, images, bbox_coords)
#       6 src_img = os.path.join(src_dir, img_name)
#       7 dst_img = os.path.join(output_dir, 'images', split, img_name)
# ----> 8 shutil.copy2(src_img, dst_img)
#      10 # Создаем YOLO аннотацию
#      11 txt_name = os.path.splitext(img_name)[0] + '.txt'
#
# File /usr/lib/python3.12/shutil.py:475, in copy2(src, dst, follow_symlinks)
#     472         else:
#     473             raise
# --> 475 copyfile(src, dst, follow_symlinks=follow_symlinks)
#     476 copystat(src, dst, follow_symlinks=follow_symlinks)
#     477 return dst
#
# File /usr/lib/python3.12/shutil.py:273, in copyfile(src, dst, follow_symlinks)
#     271 elif _USE_CP_SENDFILE:
#     272     try:
# --> 273         _fastcopy_sendfile(fsrc, fdst)
#     274         return dst
#     275     except _GiveupOnFastCopy:
#
# File /usr/lib/python3.12/shutil.py:150, in _fastcopy_sendfile(fsrc, fdst)
#     148 while True:
#     149     try:
# --> 150         sent = os.sendfile(outfd, infd, offset, blocksize)
#     151     except OSError as err:
#     152         # ...in oder to have a more informative exception.
#     153         err.filename = fsrc.name
#
# KeyboardInterrupt:
